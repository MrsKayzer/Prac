# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Информационные технологии и программирование»</b></center>
# <center>на тему</center>
# <center><b>«GitHub»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2302 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Кайзер Елизавета Михайловна</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Владимир Дмитриевич Фёдоров </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание

# %% [markdown]
# [1. Титульный лист](#Титульный_лист)
#
# <a href = '#Постановка_задач'>2. Постановка задач </a>
#
# <a href = '#Ход_работы'>3. Ход работы </a>
#
# <a href = '#Результат_выполнения_работы'>4. Результат выполнения работы </a>

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
#  ## Задание

# %% [markdown]
# Изучить материал и научится вести контроль версий.

# %% [markdown]
# ##Цель работы
# <a name = 'Цель_работы'>

# %% [markdown]
# Овладеть основами работы с системой контроля версий GIT.

# %% [markdown]
# ##Задачи работы

# %% [markdown]
# 1. Установить GIT.
# 2. Создать локальный репозиторий.
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
# 4. Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
# 5. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
# 6. Слейте последнее изменение отчета в основную ветку.
# 7. Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
# 8. Разместить на github ранее созданный статический сайт.
# 9. Завершить отчет, добавив описание всех пунктов.

# %% [markdown]
# # Ход работы
# <a name = 'Ход_работы'>

# %% [markdown]
# ###1. **Установка GIT.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###2. **Создание локального репозитория.**

# %% [markdown]
# ####1. Запуск GIT Bath.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####2. Создание папки  и размешение локального репозитория в нём.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **'cd'**: Выбор папки
# - **'git init'**: Размешение локального репозитория

# %% [markdown]
# ###3. **Помещение скаченного отчета Colab в локальный репозиторий и создание его версии.**

# %% [markdown]
# ####1. Скачивание отчета Colab.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####2. Помещение отчета с комментарием '1.0' в локальный репозиторий.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **'git add'**: добавляет файл в локальный репозиторий
# - **'git commit -m'**: создает комментарий '1.0'

# %% [markdown]
# ###4. **Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.**

# %% [markdown]
# ####1. Создание ветвей отчета.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **'git branch'**: Создает новую ветку.
# - **'git branch -a'**: Показывает все сущ ветки.

# %% [markdown]
# ####2. Выбор ветви и создание в ней папки с новой версией отчета.

# %% [markdown]
# # Результат выполнения работы
# <a name = 'Результат_выполнения_работы'>
